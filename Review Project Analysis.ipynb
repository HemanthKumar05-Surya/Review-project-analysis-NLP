# %%
#Importing required libraries
import nltk
import numpy as np
import pandas as pd
from string import punctuation
from nltk.corpus import stopwords
import warnings
warnings.filterwarnings('ignore')

# %%
#Reading the dataset and checking for first few rows
reviews0=pd.read_csv('K8 Reviews v0.2.csv')
reviews0.head()
# Out:
#    sentiment                                             review
# 0          1             Good but need updates and improvements
# 1          0  Worst mobile i have bought ever, Battery is dr...
# 2          1  when I will get my 10% cash back.... its alrea...
# 3          1                                               Good
# 4          0  The worst phone everThey have changed the last...

# %%
reviews1=list(reviews0['review'].values) # converting into list format

# %%
type(reviews1)
# Out:
# list

# %%
reviews1[0]
# Out:
# 'Good but need updates and improvements'

# %%
#Normalising casing into a lower text for easier manipulation

# %%
review_low=[rev.lower() for rev in reviews1]
review_low[0]
# Out:
# 'good but need updates and improvements'

# %%
#Tokenization of the reviews

# %%
review_tokenize=[nltk.word_tokenize(term) for term in review_low]
review_tokenize[0]
# Out:
# ['good', 'but', 'need', 'updates', 'and', 'improvements']

# %%
# Parts of speech tagging

# %%
review_pos=[nltk.pos_tag(term) for term in review_tokenize]
review_pos[5]
# Out:
# [('only', 'RB'),
#  ('i', 'JJ'),
#  ("'m", 'VBP'),
#  ('telling', 'VBG'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('buyi', 'VB'),
#  ("'m", 'VBP'),
#  ('totally', 'RB'),
#  ('disappointedpoor', 'JJ'),
#  ('batterypoor', 'JJ'),
#  ('camerawaste', 'NN'),
#  ('of', 'IN'),
#  ('money', 'NN')]

# %%
review_pos[1]
# Out:
# [('worst', 'JJS'),
#  ('mobile', 'NN'),
#  ('i', 'NN'),
#  ('have', 'VBP'),
#  ('bought', 'VBN'),
#  ('ever', 'RB'),
#  (',', ','),
#  ('battery', 'NN'),
#  ('is', 'VBZ'),
#  ('draining', 'VBG'),
#  ('like', 'IN'),
#  ('hell', 'NN'),
#  (',', ','),
#  ('backup', 'NN'),
#  ('is', 'VBZ'),
#  ('only', 'RB'),
#  ('6', 'CD'),
#  ('to', 'TO'),
#  ('7', 'CD'),
#  ('hours', 'NNS'),
#  ('with', 'IN'),
#  ('internet', 'JJ'),
#  ('uses', 'NNS'),
#  (',', ','),
#  ('even', 'RB'),
#  ('if', 'IN'),
#  ('i', 'JJ'),
#  ('put', 'VBP'),
#  ('mobile', 'JJ'),
#  ('idle', 'NN'),
#  ('its', 'PRP$'),
#  ('getting', 'VBG'),
#  ('discharged.this', 'NN'),
#  ('is', 'VBZ'),
#  ('biggest', 'JJS'),
#  ('lie', 'NN'),
#  ('from', 'IN'),
#  ('amazon', 'NN'),
#  ('&', 'CC'),
#  ('lenove', 'NN'),
#  ('which', 'WDT'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('at', 'IN'),
#  ('all', 'DT'),
#  ('expected', 'VBN'),
#  (',', ','),
#  ('they', 'PRP'),
#  ('are', 'VBP'),
#  ('making', 'VBG'),
#  ('full', 'JJ'),
#  ('by', 'IN'),
#  ('saying', 'VBG'),
#  ('that', 'DT'),
#  ('battery', 'NN'),
#  ('is', 'VBZ'),
#  ('4000mah', 'CD'),
#  ('&', 'CC'),
#  ('booster', 'JJR'),
#  ('charger', 'NN'),
#  ('is', 'VBZ'),
#  ('fake', 'JJ'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('takes', 'VBZ'),
#  ('at', 'IN'),
#  ('least', 'JJS'),
#  ('4', 'CD'),
#  ('to', 'TO'),
#  ('5', 'CD'),
#  ('hours', 'NNS'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('fully', 'RB'),
#  ('charged.do', 'VBP'),
#  ("n't", 'RB'),
#  ('know', 'VB'),
#  ('how', 'WRB'),
#  ('lenovo', 'JJ'),
#  ('will', 'MD'),
#  ('survive', 'VB'),
#  ('by', 'IN'),
#  ('making', 'VBG'),
#  ('full', 'JJ'),
#  ('of', 'IN'),
#  ('us.please', 'JJ'),
#  ('don', 'NN'),
#  (';', ':'),
#  ('t', 'CC'),
#  ('go', 'VB'),
#  ('for', 'IN'),
#  ('this', 'DT'),
#  ('else', 'JJ'),
#  ('you', 'PRP'),
#  ('will', 'MD'),
#  ('regret', 'VB'),
#  ('like', 'IN'),
#  ('me', 'PRP'),
#  ('.', '.')]

# %%
#Extracting all nouns

# %%
only_nn=[]
for term in review_pos:
    res=[sent for sent,pos in term if pos.startswith ("N") ]
    only_nn.append(res)
    
print(only_nn[0])
# Out:
# ['updates', 'improvements']

# %%
print(only_nn[1])
# Out:
# ['mobile', 'i', 'battery', 'hell', 'backup', 'hours', 'uses', 'idle', 'discharged.this', 'lie', 'amazon', 'lenove', 'battery', 'charger', 'hours', 'don']

# %%
#Lemmatization

# %%
lemma=nltk.stem.WordNetLemmatizer()
review_lema=[]
for term in only_nn:
    review_lema.append([lemma.lemmatize(word) for word in term])
    
print(review_lema[0])
# Out:
# ['update', 'improvement']

# %%
#Removing stop words and punctuation

# %%
stop_new=['lenevo']
stop_punc=list(punctuation)
stopword=stopwords.words('english')
stopnltk=stopword+stop_punc+stop_new
print(stopnltk)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", '!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~', 'lenevo']

# %%
review_sw=[]
for term in review_lema:
    re=[s for s in term if s not in stopnltk]
    review_sw.append(re)
    
print(review_sw[4])
# Out:
# ['phone', 'everthey', 'phone', 'problem', 'amazon', 'phone', 'amazon']

# %%
#Creating a topic model using LDA and downloading required libraries

# %%
import gensim
import logging
import pyLDAvis.gensim
import json
import warnings
warnings.filterwarnings('ignore')
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.ldamodel import LdaModel
from gensim.models.hdpmodel import HdpModel
from gensim.models.wrappers import LdaVowpalWabbit, LdaMallet
from gensim.corpora.dictionary import Dictionary

# %%
#printing the top 12 topics
dictionary=gensim.corpora.Dictionary(review_sw)

count=0
for k,v in dictionary.iteritems():
    print(k,v)
    count+=1
    if count>12:
        break
# Out:
# 0 improvement
# 1 update
# 2 amazon
# 3 backup
# 4 battery
# 5 charger
# 6 discharged.this
# 7 hell
# 8 hour
# 9 idle
# 10 lenove
# 11 lie
# 12 mobile

# %%
coprus=[dictionary.doc2bow(doc) for doc in review_sw]

# %%
coprus[0]
# Out:
# [(0, 1), (1, 1)]

# %%
[[(dictionary[id],freq) for id,freq in cp] for cp in coprus[0:2]]
# Out:
# [[('improvement', 1), ('update', 1)],
#  [('amazon', 1),
#   ('backup', 1),
#   ('battery', 2),
#   ('charger', 1),
#   ('discharged.this', 1),
#   ('hell', 1),
#   ('hour', 2),
#   ('idle', 1),
#   ('lenove', 1),
#   ('lie', 1),
#   ('mobile', 1),
#   ('us', 1)]]

# %%
goodLdamodel=LdaModel(corpus=coprus,id2word=dictionary,iterations=50,num_topics=2)
badLdamodel=LdaModel(corpus=coprus,id2word=dictionary,iterations=1,num_topics=2)

# %%
pyLDAvis.enable_notebook()
pyLDAvis.gensim.prepare(goodLdamodel,coprus,dictionary)
pyLDAvis.gensim.prepare(badLdamodel,coprus,dictionary)
# Out:
# PreparedData(topic_coordinates=              x    y  topics  cluster       Freq
# topic
# 1      0.010215  0.0       1        1  50.045025
# 0     -0.010215  0.0       2        1  49.954979, topic_info=    Category         Freq     Term        Total  loglift  logprob
# 4    Default  2724.000000  battery  2724.000000  30.0000  30.0000
# 60   Default  2868.000000   camera  2868.000000  29.0000  29.0000
# 52   Default  1973.000000  product  1973.000000  28.0000  28.0000
# 104  Default  1232.000000  quality  1232.000000  27.0000  27.0000
# 17   Default  6266.000000    phone  6266.000000  26.0000  26.0000
# ..       ...          ...      ...          ...      ...      ...
# 1     Topic2   182.374954   update   367.911499  -0.0077  -5.4737
# 36    Topic2   195.557892    month   443.262451  -0.1243  -5.4039
# 21    Topic2   208.272049       k8   525.582703  -0.2316  -5.3409
# 80    Topic2   202.739120  heating   523.675964  -0.2549  -5.3679
# 3     Topic2   178.066711   backup   495.841309  -0.3300  -5.4976
#
# [175 rows x 6 columns], token_table=      Topic      Freq      Term
# term
# 741       1  0.267898       ..i
# 741       2  0.669744       ..i
# 2         1  0.456137    amazon
# 2         2  0.542924    amazon
# 443       1  0.743898  anything
# ...     ...       ...       ...
# 34        2  0.717565     wrost
# 358       1  0.748698        ye
# 358       2  0.267392        ye
# 1347      1  0.766061         🔋
# 1347      2  0.255354         🔋
#
# [236 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 1])

# %%
goodcm = CoherenceModel(model=goodLdamodel, texts=review_sw, dictionary=dictionary, coherence='c_v')

# %%
badcm = CoherenceModel(model=badLdamodel, texts=review_sw, dictionary=dictionary, coherence='c_v')

# %%
print(goodcm.get_coherence())
# Out:
# 0.5316992412094479

# %%
print(badcm.get_coherence())
# Out:
# 0.4819332155984851

# %%
print(goodLdamodel.show_topics(formatted=False))
# Out:
# [(0, [('phone', 0.060922824), ('camera', 0.05421296), ('mobile', 0.027015075), ('quality', 0.023208564), ('note', 0.020912549), ('price', 0.016806997), ('feature', 0.016102208), ('battery', 0.01599488), ('lenovo', 0.012644726), ('performance', 0.011627448)]), (1, [('phone', 0.08398296), ('battery', 0.047782037), ('product', 0.040328074), ('problem', 0.02349899), ('issue', 0.022817051), ('day', 0.017149292), ('time', 0.01367765), ('money', 0.011623513), ('backup', 0.010974959), ('amazon', 0.010407343)])]

# %%
print(badLdamodel.show_topics(formatted=False))
# Out:
# [(0, [('phone', 0.08081587), ('camera', 0.045029957), ('product', 0.029052952), ('battery', 0.019334303), ('quality', 0.018492473), ('problem', 0.017343216), ('mobile', 0.014619624), ('note', 0.012436394), ('lenovo', 0.011613734), ('issue', 0.011501203)]), (1, [('phone', 0.06322564), ('battery', 0.043258913), ('camera', 0.020916006), ('mobile', 0.018258706), ('issue', 0.01721011), ('product', 0.016325124), ('problem', 0.0133937765), ('time', 0.011174554), ('day', 0.011142416), ('note', 0.010908403)])]

# %%
import pandas as pd
def format_topics_sentences(ldamodel=goodLdamodel, corpus=coprus, texts=review_sw):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=goodLdamodel, corpus=coprus, texts=review_sw)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
df_dominant_topic.head(9)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             0.0              0.8249
# 1            1             1.0              0.8811
# 2            2             1.0              0.7989
# 3            3             0.0              0.5000
# 4            4             1.0              0.9232
# 5            5             1.0              0.8017
# 6            6             0.0              0.7826
# 7            7             1.0              0.8144
# 8            8             0.0              0.7266
#
#                                             Keywords  \
# 0  phone, camera, mobile, quality, note, price, f...
# 1  phone, battery, product, problem, issue, day, ...
# 2  phone, battery, product, problem, issue, day, ...
# 3  phone, camera, mobile, quality, note, price, f...
# 4  phone, battery, product, problem, issue, day, ...
# 5  phone, battery, product, problem, issue, day, ...
# 6  phone, camera, mobile, quality, note, price, f...
# 7  phone, battery, product, problem, issue, day, ...
# 8  phone, camera, mobile, quality, note, price, f...
#
#                                                 Text
# 0                              [update, improvement]
# 1  [mobile, battery, hell, backup, hour, us, idle...
# 2                                  [cash, january..]
# 3                                                 []
# 4  [phone, everthey, phone, problem, amazon, phon...
# 5                               [camerawaste, money]
# 6                                [phone, reason, k8]
# 7                                   [battery, level]
# 8  [problem, phone, hanging, problem, note, stati...
